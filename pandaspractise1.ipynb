# %%
pip install pandas

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8327e7a8-2598-46ed-ae71-9dcfde49b6f7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8327e7a8-2598-46ed-ae71-9dcfde49b6f7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
df=pd.read_csv('Player.csv')

# %%
df.head(5) # idi first 5 rows ni display chestindi manam head lo value pass chesina chyakapoyina
# Out:
#    Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0          1       SC Ganguly  08-Jul-72    Left_Hand    Right-arm medium
# 1          2      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2          3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3          4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4          5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
#
#        Country  Is_Umpire  Unnamed: 7
# 0        India          0         NaN
# 1  New Zealand          0         NaN
# 2    Australia          0         NaN
# 3    Australia          0         NaN
# 4     Pakistan          0         NaN

# %%
df.tail() # tail ante last 5 rows of the dataset ni display chestundi argument is optional okavela ivvakapothe 5 istundi iste anni kavalooo anni istundi
# Out:
#      Player_Id   Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 518        519   Subroto Das        NaN          NaN                 NaN
# 519        520  K Srinivasan        NaN          NaN                 NaN
# 520        521     VK Sharma        NaN          NaN                 NaN
# 521        523   AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524   B Aparajith  08-Jul-94   Right_Hand  Right-arm offbreak
#
#     Country  Is_Umpire  Unnamed: 7
# 518   India          1         NaN
# 519   India          1         NaN
# 520   India          1         NaN
# 521   India          0         NaN
# 522   India          0         NaN

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df1=df.head(10)  # naku original data lo first 10 rows ki inko data frame create chyali ante then

# %%
df1.to_csv("head.csv")  # munduga head(10) ni df1 lo pedatham taravatha danni csv ki convert chestam daniki oka name istam aa name batte pilustam ee case lo head.csv ani ichamu

# %%
pd.read_csv('head.csv') # 2 index lu unnai baga chudu
# Out:
#    Unnamed: 0  Player_Id      Player_Name        DOB Batting_Hand  \
# 0           0          1       SC Ganguly  08-Jul-72    Left_Hand
# 1           1          2      BB McCullum  27-Sep-81   Right_Hand
# 2           2          3       RT Ponting  19-Dec-74   Right_Hand
# 3           3          4        DJ Hussey  15-Jul-77   Right_Hand
# 4           4          5  Mohammad Hafeez  17-Oct-80   Right_Hand
# 5           5          6         R Dravid  11-Jan-73   Right_Hand
# 6           6          7         W Jaffer  16-Feb-78   Right_Hand
# 7           7          8          V Kohli  05-Nov-88   Right_Hand
# 8           8          9        JH Kallis  16-Oct-75   Right_Hand
# 9           9         10         CL White  18-Aug-83   Right_Hand
#
#            Bowling_Skill       Country  Is_Umpire  Unnamed: 7
# 0       Right-arm medium         India          0         NaN
# 1       Right-arm medium   New Zealand          0         NaN
# ...

# %%
# !ls  # manam create chesina files anni chudaniki ee command vadatham
# Out:
#  head.csv  'Player (1).csv'   Player.csv   sample_data

# %%
df=pd.read_csv("Player.csv",sep=",",names=['a','b','c','d','e','f','g'],header=None,skiprows=[0,2,4],na_values=[1,"SC Ganguly","Right-arm medium"])
 # ikkada sep ante separator ani ardhm okavela mana dataset lo , coma kakunda #(for eg) la tho separate ayyi unte manam sep="#" cheste manam mana data ni structured way lo pondavachhu
 # header= None ante manam starting row ne header kinda bavinchalla ledaa ani
 # name=[values] idi anti ante manam mana col names marchali anukunte
 # skiprows=[enter row values] it is used to skip the rows
 # na_values=[values] means mana dataset lo adithe value nan/null cheyali anukunte aa values ikkada ivvali mana example lo "[1,"SC Ganguly","Right-arm medium"] ee values mana dataset lo akkaada unnai avi nan ayipothai"

# %%
df
# Out:
#                      a          b           c                   d          e  \
# NaN                NaN  08-Jul-72   Left_Hand                 NaN      India
# 3.0         RT Ponting  19-Dec-74  Right_Hand                 NaN  Australia
# 5.0    Mohammad Hafeez  17-Oct-80  Right_Hand  Right-arm offbreak   Pakistan
# 6.0           R Dravid  11-Jan-73  Right_Hand  Right-arm offbreak      India
# 7.0           W Jaffer  16-Feb-78  Right_Hand  Right-arm offbreak      India
# ...                ...        ...         ...                 ...        ...
# 519.0      Subroto Das        NaN         NaN                 NaN      India
# 520.0     K Srinivasan        NaN         NaN                 NaN      India
# 521.0        VK Sharma        NaN         NaN                 NaN      India
# 523.0      AV Wankhade  14-Mar-92  Right_Hand                 NaN      India
# 524.0      B Aparajith  08-Jul-94  Right_Hand  Right-arm offbreak      India
#
#          f   g
# NaN    0.0 NaN
# ...

# %%
df
# Out:
#                      a          b           c                   d          e  \
# NaN                NaN  08-Jul-72   Left_Hand                 NaN      India
# 3.0         RT Ponting  19-Dec-74  Right_Hand                 NaN  Australia
# 5.0    Mohammad Hafeez  17-Oct-80  Right_Hand  Right-arm offbreak   Pakistan
# 6.0           R Dravid  11-Jan-73  Right_Hand  Right-arm offbreak      India
# 7.0           W Jaffer  16-Feb-78  Right_Hand  Right-arm offbreak      India
# ...                ...        ...         ...                 ...        ...
# 519.0      Subroto Das        NaN         NaN                 NaN      India
# 520.0     K Srinivasan        NaN         NaN                 NaN      India
# 521.0        VK Sharma        NaN         NaN                 NaN      India
# 523.0      AV Wankhade  14-Mar-92  Right_Hand                 NaN      India
# 524.0      B Aparajith  08-Jul-94  Right_Hand  Right-arm offbreak      India
#
#          f   g
# NaN    0.0 NaN
# ...
